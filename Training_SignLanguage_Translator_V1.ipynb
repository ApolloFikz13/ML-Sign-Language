# %% [markdown]
# ## Initial Lib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Keypoint Mediapipe

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections
    
def draw_styled_landmarks(image, results):
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             ) 
    
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

# %% [markdown]
# ## Dataset

# %%
actions = np.array(['F', 'I', 'J', 'K', 'Z']) #

DATA_PATH = (r"C:\Users\victus\Documents\SignLanguage\MotionDetectionforSIBIv2\Dataset") 

no_sequences = 30

sequence_length = 30

start_folder = 30

# %%
label_map = {label:num for num, label in enumerate(actions)}
label_map
# Out:
# {'F': 0, 'I': 1, 'J': 2, 'K': 3, 'Z': 4}

# %% [markdown]
# ## Train Test

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), '{}_keypoints_{}.npy'.format(action, frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (150, 30, 258)

# %%
np.array(labels).shape
# Out:
# (150,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (150, 30, 258)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (8, 5)

# %% [markdown]
# ## Build Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import  Input, Flatten, Dense, LSTM, TimeDistributed
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import Callback

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
class StopTrainingCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if epoch > 150 and logs.get('loss') < 0.09 and (logs.get('categorical_accuracy') < 0.99 and logs.get('categorical_accuracy') > 0.88):
            print("Stopping training")
            self.model.stop_training = True
            
stop_callback = StopTrainingCallback()

# %%
lstm_input = Input(shape=(30, 258))

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,258)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=500, callbacks=[tb_callback, stop_callback]) #
# Out:
# Epoch 1/500
# 5/5 [==============================] - 2s 26ms/step - loss: 1.6087 - categorical_accuracy: 0.2535
# Epoch 2/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5448 - categorical_accuracy: 0.2958
# Epoch 3/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.3962 - categorical_accuracy: 0.4155
# Epoch 4/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.0653 - categorical_accuracy: 0.5634
# Epoch 5/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9333 - categorical_accuracy: 0.5775
# Epoch 6/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9634 - categorical_accuracy: 0.5423
# Epoch 7/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7920 - categorical_accuracy: 0.6549
# Epoch 8/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6001 - categorical_accuracy: 0.6972
# Epoch 9/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5434 - categorical_accuracy: 0.7254
# Epoch 10/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4098 - categorical_accuracy: 0.8239
# Epoch 11/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5181 - categorical_accuracy: 0.7465
# Epoch 12/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.2716 - categorical_accuracy: 0.6408
# Epoch 13/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.1204 - categorical_accuracy: 0.5915
# Epoch 14/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.9951 - categorical_accuracy: 0.5704
# Epoch 15/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8381 - categorical_accuracy: 0.5986
# Epoch 16/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7052 - categorical_accuracy: 0.5986
# Epoch 17/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5693 - categorical_accuracy: 0.7535
# Epoch 18/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6479 - categorical_accuracy: 0.7324
# Epoch 19/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5378 - categorical_accuracy: 0.6761
# Epoch 20/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5822 - categorical_accuracy: 0.7113
# Epoch 21/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4544 - categorical_accuracy: 0.7465
# Epoch 22/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4609 - categorical_accuracy: 0.7394
# Epoch 23/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.9304 - categorical_accuracy: 0.6549
# Epoch 24/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6235 - categorical_accuracy: 0.7394
# Epoch 25/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3563 - categorical_accuracy: 0.8592
# Epoch 26/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3157 - categorical_accuracy: 0.8380
# Epoch 27/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3213 - categorical_accuracy: 0.8239
# Epoch 28/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7045 - categorical_accuracy: 0.7324
# Epoch 29/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5706 - categorical_accuracy: 0.7817
# Epoch 30/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3862 - categorical_accuracy: 0.8732
# Epoch 31/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3716 - categorical_accuracy: 0.8732
# Epoch 32/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3027 - categorical_accuracy: 0.8521
# Epoch 33/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2542 - categorical_accuracy: 0.8873
# Epoch 34/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2245 - categorical_accuracy: 0.9014
# Epoch 35/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2195 - categorical_accuracy: 0.9366
# Epoch 36/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2381 - categorical_accuracy: 0.8803
# Epoch 37/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2378 - categorical_accuracy: 0.8732
# Epoch 38/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2469 - categorical_accuracy: 0.8662
# Epoch 39/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1954 - categorical_accuracy: 0.9366
# Epoch 40/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1537 - categorical_accuracy: 0.9437
# Epoch 41/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1497 - categorical_accuracy: 0.9296
# Epoch 42/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1860 - categorical_accuracy: 0.9085
# Epoch 43/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1951 - categorical_accuracy: 0.9155
# Epoch 44/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1259 - categorical_accuracy: 0.9437
# Epoch 45/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1314 - categorical_accuracy: 0.9718
# Epoch 46/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0822 - categorical_accuracy: 0.9718
# Epoch 47/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0998 - categorical_accuracy: 0.9718
# Epoch 48/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1503 - categorical_accuracy: 0.9577
# Epoch 49/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1547 - categorical_accuracy: 0.9366
# Epoch 50/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0951 - categorical_accuracy: 0.9718
# Epoch 51/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1598 - categorical_accuracy: 0.9155
# Epoch 52/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1676 - categorical_accuracy: 0.9085
# Epoch 53/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1053 - categorical_accuracy: 0.9648
# Epoch 54/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0680 - categorical_accuracy: 0.9859
# Epoch 55/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0489 - categorical_accuracy: 0.9859
# Epoch 56/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0351 - categorical_accuracy: 0.9859
# Epoch 57/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0483 - categorical_accuracy: 0.9859
# Epoch 58/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1434 - categorical_accuracy: 0.8099
# Epoch 59/500
# 5/5 [==============================] - 0s 27ms/step - loss: 3.5444 - categorical_accuracy: 0.6620
# Epoch 60/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.9899 - categorical_accuracy: 0.6127
# Epoch 61/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.9437 - categorical_accuracy: 0.6761
# Epoch 62/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9781 - categorical_accuracy: 0.5563
# Epoch 63/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6596 - categorical_accuracy: 0.7394
# Epoch 64/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5044 - categorical_accuracy: 0.8239
# Epoch 65/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3826 - categorical_accuracy: 0.7887
# Epoch 66/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8419 - categorical_accuracy: 0.7183
# Epoch 67/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5911 - categorical_accuracy: 0.7254
# Epoch 68/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5437 - categorical_accuracy: 0.8662
# Epoch 69/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5765 - categorical_accuracy: 0.7817
# Epoch 70/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6668 - categorical_accuracy: 0.7394
# Epoch 71/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5807 - categorical_accuracy: 0.7746
# Epoch 72/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3319 - categorical_accuracy: 0.8169
# Epoch 73/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2873 - categorical_accuracy: 0.8803
# Epoch 74/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2757 - categorical_accuracy: 0.8592
# Epoch 75/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3017 - categorical_accuracy: 0.8592
# Epoch 76/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3744 - categorical_accuracy: 0.8521
# Epoch 77/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3455 - categorical_accuracy: 0.8451
# Epoch 78/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2874 - categorical_accuracy: 0.8592
# Epoch 79/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2859 - categorical_accuracy: 0.8732
# Epoch 80/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2726 - categorical_accuracy: 0.8451
# Epoch 81/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2215 - categorical_accuracy: 0.9437
# Epoch 82/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2349 - categorical_accuracy: 0.8873
# Epoch 83/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2004 - categorical_accuracy: 0.9225
# Epoch 84/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1916 - categorical_accuracy: 0.9437
# Epoch 85/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1801 - categorical_accuracy: 0.9225
# Epoch 86/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1914 - categorical_accuracy: 0.9155
# Epoch 87/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1705 - categorical_accuracy: 0.9507
# Epoch 88/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1537 - categorical_accuracy: 0.9296
# Epoch 89/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1453 - categorical_accuracy: 0.9366
# Epoch 90/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1364 - categorical_accuracy: 0.9577
# Epoch 91/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8543 - categorical_accuracy: 0.8521
# Epoch 92/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5468 - categorical_accuracy: 0.6056
# Epoch 93/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6972 - categorical_accuracy: 0.7042
# Epoch 94/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8155 - categorical_accuracy: 0.6620
# Epoch 95/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6329 - categorical_accuracy: 0.7606
# Epoch 96/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5197 - categorical_accuracy: 0.7324
# Epoch 97/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7055 - categorical_accuracy: 0.6972
# Epoch 98/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.9334 - categorical_accuracy: 0.5704
# Epoch 99/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6790 - categorical_accuracy: 0.7042
# Epoch 100/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5287 - categorical_accuracy: 0.7465
# Epoch 101/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4725 - categorical_accuracy: 0.7535
# Epoch 102/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5150 - categorical_accuracy: 0.7183
# Epoch 103/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5106 - categorical_accuracy: 0.7113
# Epoch 104/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3860 - categorical_accuracy: 0.7746
# Epoch 105/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3388 - categorical_accuracy: 0.7817
# Epoch 106/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3530 - categorical_accuracy: 0.7958
# Epoch 107/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3399 - categorical_accuracy: 0.8028
# Epoch 108/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3180 - categorical_accuracy: 0.8028
# Epoch 109/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2984 - categorical_accuracy: 0.8239
# Epoch 110/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3326 - categorical_accuracy: 0.8028
# Epoch 111/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2742 - categorical_accuracy: 0.8451
# Epoch 112/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2508 - categorical_accuracy: 0.9085
# Epoch 113/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2321 - categorical_accuracy: 0.9014
# Epoch 114/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2441 - categorical_accuracy: 0.8873
# Epoch 115/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2527 - categorical_accuracy: 0.8521
# Epoch 116/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2558 - categorical_accuracy: 0.8732
# Epoch 117/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2560 - categorical_accuracy: 0.8662
# Epoch 118/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2864 - categorical_accuracy: 0.8169
# Epoch 119/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2622 - categorical_accuracy: 0.8732
# Epoch 120/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2721 - categorical_accuracy: 0.8169
# Epoch 121/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2503 - categorical_accuracy: 0.8803
# Epoch 122/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2650 - categorical_accuracy: 0.8521
# Epoch 123/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2634 - categorical_accuracy: 0.8803
# Epoch 124/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2328 - categorical_accuracy: 0.8803
# Epoch 125/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2768 - categorical_accuracy: 0.8451
# Epoch 126/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6702 - categorical_accuracy: 0.7324
# Epoch 127/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5490 - categorical_accuracy: 0.7676
# Epoch 128/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6742 - categorical_accuracy: 0.7535
# Epoch 129/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5488 - categorical_accuracy: 0.7606
# Epoch 130/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3721 - categorical_accuracy: 0.8310
# Epoch 131/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3546 - categorical_accuracy: 0.8662
# Epoch 132/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2814 - categorical_accuracy: 0.8803
# Epoch 133/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2426 - categorical_accuracy: 0.9014
# Epoch 134/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2505 - categorical_accuracy: 0.8592
# Epoch 135/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2166 - categorical_accuracy: 0.9155
# Epoch 136/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2088 - categorical_accuracy: 0.9155
# Epoch 137/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3060 - categorical_accuracy: 0.8380
# Epoch 138/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2557 - categorical_accuracy: 0.8592
# Epoch 139/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2639 - categorical_accuracy: 0.8592
# Epoch 140/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2718 - categorical_accuracy: 0.8521
# Epoch 141/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2818 - categorical_accuracy: 0.8521
# Epoch 142/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1867 - categorical_accuracy: 0.8944
# Epoch 143/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2100 - categorical_accuracy: 0.9437
# Epoch 144/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1681 - categorical_accuracy: 0.9366
# Epoch 145/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1647 - categorical_accuracy: 0.9437
# Epoch 146/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1574 - categorical_accuracy: 0.9507
# Epoch 147/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1705 - categorical_accuracy: 0.9225
# Epoch 148/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2549 - categorical_accuracy: 0.8803
# Epoch 149/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3099 - categorical_accuracy: 0.8662
# Epoch 150/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1795 - categorical_accuracy: 0.9225
# Epoch 151/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1887 - categorical_accuracy: 0.9225
# Epoch 152/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1921 - categorical_accuracy: 0.9225
# Epoch 153/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1958 - categorical_accuracy: 0.9014
# Epoch 154/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1595 - categorical_accuracy: 0.9366
# Epoch 155/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1632 - categorical_accuracy: 0.9437
# Epoch 156/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1395 - categorical_accuracy: 0.9648
# Epoch 157/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1538 - categorical_accuracy: 0.9366
# Epoch 158/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1104 - categorical_accuracy: 0.9507
# Epoch 159/500
# 3/5 [=================>............] - ETA: 0s - loss: 0.0986 - categorical_accuracy: 0.9583Stopping training
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0876 - categorical_accuracy: 0.9648

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 30, 64)            82688
#
#  lstm_13 (LSTM)              (None, 30, 128)           98816
#
#  lstm_14 (LSTM)              (None, 64)                49408
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dense_14 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 237,317
# Trainable params: 237,317
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[6, 0],
#         [0, 2]],
#
#        [[6, 0],
#         [0, 2]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[5, 0],
#         [0, 3]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# ## Save and Reload Model

# %%
model.save('abjadV1.h5')

# %%
del model

# %%
model.load_weights('abjadV1.h5')

# %% [markdown]
# ## Real Time test

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.3, min_tracking_confidence=0.3) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

        height, width, channels = image.shape
        text_size, _ = cv2.getTextSize(' '.join(sentence), cv2.FONT_HERSHEY_SIMPLEX, 1, 2)
        text_width = text_size[0]
        x = (width - text_width) // 2
        cv2.putText(image, ' '.join(sentence), (x, height - 40), 
        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Z
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# J
